# %%
import os
import pandas as pd
import multiprocessing as mp
import json

from sfe import Graph, SFE
from helpers import save_features_to_disk
import time


def pipeline(
    # Files & Directories paths
    pra_graph_input_path, # list containing the path to where the tsv files containing set of triples to be used to build the graph are, e.g., `XKE/benchmarks/FB13/pra_graph_input/`. There should be `train.tsv` and `valid.tsv` files. Each line should contain the head, relation and tail of an existing triple, in the mentioned order.
    datasets_paths, # list containing the path for each dataset for which features will be extracted. The dataset file should be a TSV file containing the columns (in the order): head, relation, tail, label
    output_dir, # path for the output dir, the directory where results will be saved

    # SFE options
    max_depth=2,
    max_fan_out=100,
    bfs_memory_size=1000,
    batch_size=10000, # number of features that will be processed in a row before saving them to disk (and freeing up memory space). Notice that this applies to each Process, so in practice this number is multiplied by the number of cores.
):

    # SAVE HYPERPARAMS TO DISK
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    params_str = json.dumps(locals())
    with open(os.path.join(output_dir, 'hyperparameters.json'), 'w') as f:
        f.write(params_str)

    # BUILD GRAPH
    g = Graph()
    train = pd.read_csv(os.path.join(pra_graph_input_path, 'train.tsv'), sep='\t', skiprows=0, names=['head', 'relation', 'tail'])
    valid = pd.read_csv(os.path.join(pra_graph_input_path, 'valid.tsv'), sep='\t', skiprows=0, names=['head', 'relation', 'tail'])
    print("Building graph..."),
    g.partial_build_from_df(train)
    g.partial_build_from_df(valid)
    print("Built.")


    # EXTRACT FEATURES
    sfe = SFE(g, max_depth, max_fan_out, bfs_memory_size)
    return sfe

# %%
dataset_str = 'NELL186'

sfe = pipeline(
    # Files & Directories paths
    pra_graph_input_path=\
        '../benchmarks/{}/pra_graph_input/'.format(dataset_str),
    datasets_paths=[
        '../benchmarks/{}/corrupted/train.txt'.format(dataset_str),
        '../benchmarks/{}/valid.txt'.format(dataset_str),
        '../benchmarks/{}/test.txt'.format(dataset_str),
    ], 
    output_dir=\
        './results/{}/{}'.format(dataset_str, int(time.time())),
    # SFE options
    max_depth=2,
    max_fan_out=100,
    bfs_memory_size=1000,
    batch_size=10000, # number of features that will be processed in a row before saving them to disk (and freeing up memory space). Notice that this applies to each Process, so in practice this number is multiplied by the number of cores.
)
# Out:
#   File "<ipython-input-12-fbe82b1cca16>", line 22
#     datasets_paths=[
#     ^
# IndentationError: unexpected indent

# %%
# define parameters in this scope
pra_graph_input_path=\
    '../benchmarks/{}/pra_graph_input/'.format(dataset_str)
datasets_paths=[
    '../benchmarks/{}/corrupted/train.txt'.format(dataset_str),
    '../benchmarks/{}/valid.txt'.format(dataset_str),
    '../benchmarks/{}/test.txt'.format(dataset_str),
]
output_dir=\
    './results/{}/{}'.format(dataset_str, int(time.time()))
# SFE options
max_depth=2
max_fan_out=100
bfs_memory_size=1000
batch_size=10000 # number of features that will be processed in a row before saving them to disk (and freeing up memory space). Notice that this applies to each Process, so in practice this number is multiplied by the number of cores.

# %% [markdown]
# # Debug

# %%
sfe.

# %% [markdown]
# # Last steps of pipeline

# %%
for filepath in datasets_paths:
    print("\nStarting feature extraction for `{}` ...".format(filepath))
    df = pd.read_csv(filepath, sep='\t', skiprows=0, names=['head', 'relation', 'tail', 'label'])
    df = df.sort_values(by=['head', 'tail']) # this is important if multiprocessing to help SFE save computing time using the BFS memory
    output_file_name = os.path.basename(filepath).replace('.txt', '.tsv')

    # @TODO: put this into multiprocessing (or maybe threading)
    count = 0
    for res in sfe.extract_features(df, batch_size=batch_size):
        save_features_to_disk(res, output_dir, output_file_name)
        count += batch_size
        print("{} examples processed...".format(count))

print("\nPipeline finished.")
# Out:
# Starting feature extraction for `../benchmarks/NELL186/corrupted/train.txt` ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-7c819cd956e4> in <module>()
#       7     # @TODO: put this into multiprocessing (or maybe threading)
#       8     count = 0
# ----> 9     for res in sfe.extract_features(df, batch_size=batch_size):
#      10         save_features_to_disk(res, output_dir, output_file_name)
#      11         count += batch_size
#
# /mnt/c/Users/egsmrth/Projects/xke/sfe/sfe.pyc in extract_features(self, df, batch_size)
#     255             label = row.get('label', None)
#     256
# --> 257             paths = self.search_paths(head, tail)
#     258             output[rel].append({
#     259                 'entity_pair': (head, tail),
#
# /mnt/c/Users/egsmrth/Projects/xke/sfe/sfe.pyc in search_paths(self, head_name, tail_name)
#     220         """
#     221         last_time = time.time()
# --> 222         head = self.graph.get_node(head_name)
#     223         tail = self.graph.get_node(tail_name)
#     224         # print "time get nodes: {}".format(time.time() - last_time); last_time = time.time()
#
# /mnt/c/Users/egsmrth/Projects/xke/sfe/sfe.pyc in get_node(self, name, create)
#      49         if create and not name in self.nodes:
#      50             self.nodes[name] = Node(name)
# ---> 51         return self.nodes[name]
#      52
#      53     def partial_build_from_df(self, df):
#
# KeyError: 'concept:academicfield:accountancy'

# %%
sfe.graph.get_node('concept:academicfield:accountancy')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-62c54071381f> in <module>()
# ----> 1 sfe.graph.get_node('concept:academicfield:accountancy')
#
# /mnt/c/Users/egsmrth/Projects/xke/sfe/sfe.pyc in get_node(self, name, create)
#      49         if create and not name in self.nodes:
#      50             self.nodes[name] = Node(name)
# ---> 51         return self.nodes[name]
#      52
#      53     def partial_build_from_df(self, df):
#
# KeyError: 'concept:academicfield:accountancy'

# %%
sfe.graph.get_node('concept:coach:mark_hendrickson')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-f69ea9fb8ee5> in <module>()
# ----> 1 sfe.graph.get_node('concept:coach:mark_hendrickson')
#
# /mnt/c/Users/egsmrth/Projects/xke/sfe/sfe.pyc in get_node(self, name, create)
#      49         if create and not name in self.nodes:
#      50             self.nodes[name] = Node(name)
# ---> 51         return self.nodes[name]
#      52
#      53     def partial_build_from_df(self, df):
#
# KeyError: 'concept:coach:mark_hendrickson'

# %%
sfe.graph.nodes
# Out:
# {nan: <sfe.Node at 0x7f3f74751a50>,
#  nan: <sfe.Node at 0x7f3f74751d10>,
#  '15355,concept:fish:tuna,concept:fishservedwithfood,concept:food:crust': <sfe.Node at 0x7f3f713ee050>,
#  nan: <sfe.Node at 0x7f3f6f42ced0>,
#  nan: <sfe.Node at 0x7f3f73edde10>,
#  '12448,concept:clothing:trousers,concept:clothingtogowithclothing,concept:clothing:blouse': <sfe.Node at 0x7f3f71c12b90>,
#  nan: <sfe.Node at 0x7f3f700e72d0>,
#  nan: <sfe.Node at 0x7f3f6ff33dd0>,
#  nan: <sfe.Node at 0x7f3f73102d50>,
#  '11590,concept:city:woburn,concept:atlocation,concept:stateorprovince:massachusetts': <sfe.Node at 0x7f3f71ea57d0>,
#  '25905,concept:sportsteam:baltimore_ravens,concept:teamwontrophy,concept:awardtrophytournament:afc_championship': <sfe.Node at 0x7f3f6f5f6ed0>,
#  '9589,concept:city:boone,concept:atlocation,concept:geopoliticallocation:north_carolina': <sfe.Node at 0x7f3f72773f50>,
#  '6574,concept:beverage:tea,concept:agriculturalproductcontainchemical,concept:chemical:acid': <sfe.Node at 0x7f3f72fe8410>,
#  '16952,concept:geopoliticallocation:warsaw,concept:locationlocatedwithinlocation,concept:country:poland': <sfe.Node at 0x7f3f70f6eb50>,
#  '13065,concept:coach:zdeno_chara,concept:athleteplaysforteam,concept:sportsteam:bruins': <sfe.Node at 0x7f3f71a5e510>,
#  nan: <sfe.Node at 0x7f3f73c62290>,
#  '6211,concept:bank:hsbc,concept:bankbankincountry,concept:country:qatar': <sfe.Node at 0x7f3f73154b90>,
#  '31061,concept:winery:blackstone,concept:wineryproduceswine,concept:wine:cabernet_sauvignon': <sfe.Node at 0x7f3f6e7359d0>,
#  nan: <sfe.Node at 0x7f3f70568cd0>,
#  nan: <sfe.Node at 0x7f3f71f48610>,
#  nan: <sfe.Node at 0x7f3f6e2d84d0>,
#  nan: <sfe.Node at 0x7f3f7033e4d0>,
#  nan: <sfe.Node at 0x7f3f727c5890>,
#  nan: <sfe.Node at 0x7f3f6e1b1290>,
#  '4604,concept:country:u__s,concept:countryalsoknownas,concept:country:taiwan,1': <sfe.Node at 0x7f3f6e08b110>,
#  nan: <sfe.Node at 0x7f3f700e7350>,
#  nan: <sfe.Node at 0x7f3f733a20d0>,
#  '2309,concept:arthropod:deer,concept:animalpreyson,concept:animal:mammals001': <sfe.Node at 0x7f3f73d65e90>,
#  nan: <sfe.Node at 0x7f3f6f98bb90>,
#  nan: <sfe.Node at 0x7f3f70ddec90>,
#  nan: <sfe.Node at 0x7f3f709c64d0>,
#  '24512,concept:professionalorganization:lions,concept:organizationhiredperson,concept:coach:marinelli': <sfe.Node at 0x7f3f6fa01b50>,
#  nan: <sfe.Node at 0x7f3f6e0397d0>,
#  '16177,concept:furniture:bed,concept:furniturefoundinroom,concept:room:huge_room': <sfe.Node at 0x7f3f711c51d0>,
#  '1961,concept:animal:toddlers,concept:animaldevelopdisease,concept:disease:disabilities': <sfe.Node at 0x7f3f73e67dd0>,
#  '12545,concept:coach:bill_callahan,concept:coachesteam,concept:sportsteam:oakland_raiders': <sfe.Node at 0x7f3f71bd7cd0>,
#  nan: <sfe.Node at 0x7f3f6ff33e50>,
#  '13249,concept:company:british_airways,concept:atlocation,concept:airport:gatwick': <sfe.Node at 0x7f3f719e8290>,
#  nan: <sfe.Node at 0x7f3f709c6d50>,
#  '24402,concept:politicianus:w__bush,concept:politicianusendorsedbypoliticianus,concept:politicianus:karl_rove': <sfe.Node at 0x7f3f6fa3c390>,
#  '9432,concept:university:cu,concept:organizationhiredperson,concept:coach:dan_hawkins,1': <sfe.Node at 0x7f3f6d960b10>,
#  '17563,concept:journalist:andrew_ross_sorkin,concept:worksfor,concept:newspaper:new_york_times': <sfe.Node at 0x7f3f70dba1d0>,
#  nan: <sfe.Node at 0x7f3f7052df90>,
#  nan: <sfe.Node at 0x7f3f71e52410>,
#  '28474,concept:stateorprovince:maharashtra,concept:subpartof,concept:country:india__': <sfe.Node at 0x7f3f6ee567d0>,
#  '22693,concept:plant:conifer,concept:plantincludeplant,concept:plant:trees': <sfe.Node at 0x7f3f6ff4af50>,
#  nan: <sfe.Node at 0x7f3f72c6af90>,
#  '22492,concept:personmexico:zach_miner,concept:athleteplaysinleague,concept:sportsleague:mlb': <sfe.Node at 0x7f3f6ffc0950>,
#  '11326,concept:city:st___petersburg,concept:cityliesonriver,concept:river:mississippi': <sfe.Node at 0x7f3f71f6c1d0>,
#  '748,concept:arthropod:invertebrates,concept:animalthatfeedoninsect,concept:insect:ants,1': <sfe.Node at 0x7f3f6e5f8d90>,
#  nan: <sfe.Node at 0x7f3f72b681d0>,
#  nan: <sfe.Node at 0x7f3f70a602d0>,
#  '10304,concept:city:houma,concept:atlocation,concept:stateorprovince:louisiana': <sfe.Node at 0x7f3f72585a90>,
#  nan: <sfe.Node at 0x7f3f6dfd0690>,
#  '29078,concept:televisionstation:kvbc,concept:televisionstationincity,concept:city:los_angeles': <sfe.Node at 0x7f3f6ed0ba90>,
#  nan: <sfe.Node at 0x7f3f6fa01d90>,
#  nan: <sfe.Node at 0x7f3f70ef7e90>,
#  '14201,concept:country:malaysia,concept:countrylocatedingeopoliticallocation,concept:country:muslim_countries': <sfe.Node at 0x7f3f7171a610>,
#  nan: <sfe.Node at 0x7f3f7039d590>,
#  '18326,concept:language:latin,concept:languageofuniversity,concept:university:johns_hopkins_university': <sfe.Node at 0x7f3f70b62550>,
#  '7770,concept:ceo:abigail_johnson,concept:personleadsorganization,concept:company:fidelity_investments': <sfe.Node at 0x7f3f72cd3390>,
#  '29923,concept:vegetable:pepper,concept:agriculturalproductcookedwithagriculturalproduct,concept:agriculturalproduct:scallions': <sfe.Node at 0x7f3f6ea787d0>,
#  nan: <sfe.Node at 0x7f3f7160b050>,
#  nan: <sfe.Node at 0x7f3f6e5540d0>,
#  '30230,concept:visualartist:escher,concept:visualartistartform,concept:visualartform:paintings': <sfe.Node at 0x7f3f6e95f3d0>,
#  '8526,concept:sportsteam:idaho_state,concept:teamplaysincity,concept:city:pocatello,1': <sfe.Node at 0x7f3f6da9d510>,
#  nan: <sfe.Node at 0x7f3f6ffe4a10>,
#  '2484,concept:arthropod:spider_bite,concept:arthropodcalledarthropod,concept:arachnid:brown_recluse_spider': <sfe.Node at 0x7f3f73cee790>,
#  '1074,concept:agriculturalproduct:silk,concept:agriculturalproductcamefromcountry,concept:country:kazakhstan': <sfe.Node at 0x7f3f740e3b50>,
#  '24975,concept:room:unit,concept:subpartof,concept:weatherphenomenon:water': <sfe.Node at 0x7f3f6f85b690>,
#  '3086,concept:city:brownsville,concept:subpartof,concept:stateorprovince:texas,1': <sfe.Node at 0x7f3f6e2cbf50>,
#  '2802,concept:athlete:brandon_bass,concept:athleteplaysinleague,concept:sportsleague:nfl': <sfe.Node at 0x7f3f73bd5910>,
#  '23431,concept:politicianus:biden,concept:politicianusendorsedbypoliticianus,concept:politicianus:barack': <sfe.Node at 0x7f3f6fcf3650>,
#  nan: <sfe.Node at 0x7f3f6e6916d0>,
#  '17470,concept:invertebrate:hedgehogs,concept:animalpreyson,concept:animal:animals002': <sfe.Node at 0x7f3f70df5290>,
#  nan: <sfe.Node at 0x7f3f70466710>,
#  '26148,concept:sportsteam:chargers,concept:organizationhiredperson,concept:coach:marty_schottenheimer': <sfe.Node at 0x7f3f6f52fa50>,
#  '6420,concept:beverage:gelatin,concept:beveragemadefrombeverage,concept:beverage:juice': <sfe.Node at 0x7f3f730755d0>,
#  '4514,concept:country:england,concept:organizationhiredperson,concept:personaustralia:fabio_capello,1': <sfe.Node at 0x7f3f6e05ca10>,
#  nan: <sfe.Node at 0x7f3f6ede0a10>,
#  nan: <sfe.Node at 0x7f3f72fdb110>,
#  '14874,concept:drug:nexium,concept:drugworkedonbyagent,concept:biotechcompany:astrazeneca': <sfe.Node at 0x7f3f7157ebd0>,
#  '4774,concept:athlete:sean_gallagher,concept:athleteplayssport,concept:sport:baseball': <sfe.Node at 0x7f3f735481d0>,
#  '19495,concept:meat:chicken,concept:agriculturalproductcutintogeometricshape,concept:geometricshape:bite_size_pieces': <sfe.Node at 0x7f3f70836710>,
#  '9854,concept:city:dakar,concept:citylocatedincountry,concept:country:senegal': <sfe.Node at 0x7f3f726c2610>,
#  nan: <sfe.Node at 0x7f3f70363dd0>,
#  '16354,concept:furniture:beds,concept:furniturefoundinroom,concept:room:one_large_room': <sfe.Node at 0x7f3f71138b90>,
#  '1310,concept:airport:mariscal_sucre,concept:airportincity,concept:city:quito': <sfe.Node at 0x7f3f7401b350>,
#  '9152,concept:chemical:sulfur,concept:chemicalistypeofchemical,concept:chemical:water_vapor': <sfe.Node at 0x7f3f728c7190>,
#  '15113,concept:female:dionne_warwick,concept:personhasresidenceincity,concept:city:east_orange': <sfe.Node at 0x7f3f714b6550>,
#  '11071,concept:city:prescott,concept:cityliesonriver,concept:river:mississippi': <sfe.Node at 0x7f3f72034050>,
#  nan: <sfe.Node at 0x7f3f71f48690>,
#  '2487,concept:arthropod:widow,concept:animalistypeofanimal,concept:invertebrate:spider': <sfe.Node at 0x7f3f73cee910>,
#  '8620,concept:sportsteam:miami_fl_hurricanes,concept:teamplaysincity,concept:city:raleigh,1': <sfe.Node at 0x7f3f6dab5cd0>,
#  '20584,concept:person:anne_mulcahy,concept:worksfor,concept:company:xerox001': <sfe.Node at 0x7f3f704dc050>,
#  '6658,concept:person:bill,concept:worksfor,concept:biotechcompany:microsoft,1': <sfe.Node at 0x7f3f6dd6ba90>,
#  nan: <sfe.Node at 0x7f3f72ee5990>,
#  nan: <sfe.Node at 0x7f3f7033e550>,
#  '18095,concept:language:english,concept:languageofuniversity,concept:university:london_university': <sfe.Node at 0x7f3f70c2afd0>,
#  '21238,concept:person:jon001,concept:persongraduatedfromuniversity,concept:university:state_university': <sfe.Node at 0x7f3f70328c50>,
#  '3750,concept:clothing:hat,concept:clothingmadefromplant,concept:plant:flower,1': <sfe.Node at 0x7f3f6e1c9810>,
#  '12422,concept:clothing:ties,concept:clothingtogowithclothing,concept:clothing:tuxedos': <sfe.Node at 0x7f3f71c7be50>,
#  nan: <sfe.Node at 0x7f3f6e50b050>,
#  '12867,concept:coach:mark_hendrickson,concept:coachesinleague,concept:sportsleague:mlb': <sfe.Node at 0x7f3f71ad4090>,
#  nan: <sfe.Node at 0x7f3f6ef70290>,
#  nan: <sfe.Node at 0x7f3f74749210>,
#  nan: <sfe.Node at 0x7f3f71784190>,
#  nan: <sfe.Node at 0x7f3f6e3b6e10>,
#  nan: <sfe.Node at 0x7f3f6e1b1310>,
#  nan: <sfe.Node at 0x7f3f6e821210>,
#  '6524,concept:musician:paul,concept:musicianplaysinstrument,concept:musicinstrument:bass,1': <sfe.Node at 0x7f3f6ddbd890>,
#  nan: <sfe.Node at 0x7f3f6df95bd0>,
#  '9703,concept:city:carrollton,concept:atlocation,concept:stateorprovince:texas': <sfe.Node at 0x7f3f7274f950>,
#  nan: <sfe.Node at 0x7f3f6fa25890>,
#  '537,concept:agriculturalproduct:black_pepper,concept:agriculturalproductcookedwithagriculturalproduct,concept:vegetable:onions': <sfe.Node at 0x7f3f7425ca90>,
#  '29876,concept:vegetable:pepper,concept:agriculturalproductcookedwithagriculturalproduct,concept:agriculturalproduct:broccoli': <sfe.Node at 0x7f3f6eacafd0>,
#  '10653,concept:city:mbabane,concept:citylocatedincountry,concept:country:swaziland': <sfe.Node at 0x7f3f72481bd0>,
#  '11929,concept:clothing:jeans,concept:clothingtogowithclothing,concept:clothing:boots': <sfe.Node at 0x7f3f71da1410>,
#  '24330,concept:politicianus:senator_joe_biden,concept:politicianholdsoffice,concept:politicaloffice:senator': <sfe.Node at 0x7f3f6fa78ed0>,
#  '5753,concept:automobilemodel:testing,concept:subpartof,concept:weatherphenomenon:water': <sfe.Node at 0x7f3f73292310>,
#  nan: <sfe.Node at 0x7f3f6fe54790>,
#  nan: <sfe.Node at 0x7f3f702ed850>,
#  '10222,concept:city:hanover,concept:atlocation,concept:stateorprovince:pennsylvania': <sfe.Node at 0x7f3f725d6110>,
#  '29683,concept:university:notre_dame,concept:organizationhiredperson,concept:coach:tyrone_willingham': <sfe.Node at 0x7f3f6eb41dd0>,
#  '6200,concept:bank:federal_bank,concept:bankbankincountry,concept:country:india__': <sfe.Node at 0x7f3f73154610>,
#  nan: <sfe.Node at 0x7f3f73ddbbd0>,
#  nan: <sfe.Node at 0x7f3f6f50bf90>,
#  nan: <sfe.Node at 0x7f3f6ecb9b50>,
#  nan: <sfe.Node at 0x7f3f709aef90>,
#  nan: <sfe.Node at 0x7f3f74297810>,
#  nan: <sfe.Node at 0x7f3f729eff10>,
#  nan: <sfe.Node at 0x7f3f7411e550>,
#  '6820,concept:person:kathy,concept:personmovedtostateorprovince,concept:stateorprovince:california,1': <sfe.Node at 0x7f3f6dd303d0>,
#  '16245,concept:furniture:beds,concept:furniturefoundinroom,concept:room:second_smaller_bedroom': <sfe.Node at 0x7f3f71173450>,
#  '17707,concept:journalist:elizabeth_vargas,concept:journalistwritesforpublication,concept:company:abc001': <sfe.Node at 0x7f3f70d16ad0>,
#  '10782,concept:city:mumbai,concept:citylocatedinstate,concept:stateorprovince:maharashtra': <sfe.Node at 0x7f3f7245dd50>,
#  nan: <sfe.Node at 0x7f3f72ec2090>,
#  nan: <sfe.Node at 0x7f3f70dded10>,
#  '25166,concept:sport:bowling,concept:sportusesequipment,concept:sportsequipment:pin': <sfe.Node at 0x7f3f6f7e5790>,
#  nan: <sfe.Node at 0x7f3f73532150>,
#  '4271,concept:athlete:micah_owings,concept:athleteplaysinleague,concept:sportsleague:mlb': <sfe.Node at 0x7f3f736d8250>,
#  '8782,concept:chemical:hydrocarbons,concept:chemicalistypeofchemical,concept:chemical:sulphur': <sfe.Node at 0x7f3f729b4590>,
#  nan: <sfe.Node at 0x7f3f709c6550>,
#  '25069,concept:sport:baseball,concept:sportusesequipment,concept:sportsequipment:apparel': <sfe.Node at 0x7f3f6f820650>,
#  '12123,concept:clothing:shirts,concept:clothingtogowithclothing,concept:clothing:sleeve_shirts': <sfe.Node at 0x7f3f71d2c690>,
#  nan: <sfe.Node at 0x7f3f7394ab10>,
#  nan: <sfe.Node at 0x7f3f6dcba110>,
#  '30359,concept:visualartist:picasso,concept:visualartistartform,concept:visualartform:sculptures': <sfe.Node at 0x7f3f6e93a550>,
#  nan: <sfe.Node at 0x7f3f70ffa8d0>,
#  nan: <sfe.Node at 0x7f3f7313d710>,
#  '19062,concept:mammal:horse,concept:animaldevelopdisease,concept:disease:rabies': <sfe.Node at 0x7f3f70973b10>,
#  nan: <sfe.Node at 0x7f3f6e1d5c90>,
#  nan: <sfe.Node at 0x7f3f6d9d6dd0>,
#  '29117,concept:televisionstation:kxas,concept:televisionstationincity,concept:city:dallas': <sfe.Node at 0x7f3f6eca2e50>,
#  '21591,concept:person:patrick_taylor,concept:hasspouse,concept:person:rachel_griffiths': <sfe.Node at 0x7f3f70224f90>,
#  '1059,concept:agriculturalproduct:seasonings,concept:agriculturalproductcookedwithagriculturalproduct,concept:agriculturalproduct:chicken_breast': <sfe.Node at 0x7f3f740e33d0>,
#  nan: <sfe.Node at 0x7f3f717913d0>,
#  nan: <sfe.Node at 0x7f3f70f84e50>,
#  '9625,concept:city:bristol,concept:cityliesonriver,concept:geopoliticalorganization:avon': <sfe.Node at 0x7f3f727211d0>,
#  nan: <sfe.Node at 0x7f3f6fe6b050>,
#  '12628,concept:coach:charlie_weis,concept:worksfor,concept:university:notre_dame': <sfe.Node at 0x7f3f71b9c710>,
#  nan: <sfe.Node at 0x7f3f711aefd0>,
#  nan: <sfe.Node at 0x7f3f706a64d0>,
#  nan: <sfe.Node at 0x7f3f6f4a19d0>,
#  nan: <sfe.Node at 0x7f3f731ca3d0>,
#  '1492,concept:athlete:raul_valdes,concept:athleteplaysinleague,concept:sportsleague:mlb,1': <sfe.Node at 0x7f3f6e50ba90>,
#  '2461,concept:arthropod:prey,concept:animalsuchasinvertebrate,concept:invertebrate:worms': <sfe.Node at 0x7f3f73cd8bd0>,
#  nan: <sfe.Node at 0x7f3f6dcba210>,
#  '27118,concept:sportsteam:new_orleans_privateers,concept:teamplaysinleague,concept:sportsleague:ncaa': <sfe.Node at 0x7f3f6f278710>,
#  '30912,concept:website:philadelphia_inquirer,concept:headquarteredin,concept:city:new_york_city': <sfe.Node at 0x7f3f6e7c2e10>,
#  '20134,concept:musician:josh,concept:musicianplaysinstrument,concept:musicinstrument:percussion': <sfe.Node at 0x7f3f70682b90>,
#  nan: <sfe.Node at 0x7f3f6e1c9cd0>,
#  nan: <sfe.Node at 0x7f3f71e2ef90>,
#  nan: <sfe.Node at 0x7f3f6efab8d0>,
#  nan: <sfe.Node at 0x7f3f706a6050>,
#  '15912,concept:furniture:bed,concept:furniturefoundinroom,concept:room:air_conditioned_bedroom': <sfe.Node at 0x7f3f71275b10>,
#  nan: <sfe.Node at 0x7f3f6f100610>,
#  '310,concept:agriculturalproduct:salt,concept:agriculturalproductcutintogeometricshape,concept:geometricshape:bits,1': <sfe.Node at 0x7f3f6e656e50>,
#  nan: <sfe.Node at 0x7f3f70647f90>,
#  nan: <sfe.Node at 0x7f3f72c6ae10>,
#  nan: <sfe.Node at 0x7f3f72ed9850>,
#  nan: <sfe.Node at 0x7f3f6ff33ed0>,
#  '25817,concept:sportsteam:albany_state_golden_rams,concept:subpartoforganization,concept:sportsteam:ncaa': <sfe.Node at 0x7f3f6f648250>,
#  nan: <sfe.Node at 0x7f3f6f5460d0>,
#  '16748,concept:furniture:sleeper,concept:furniturefoundinroom,concept:room:unit': <sfe.Node at 0x7f3f70fe33d0>,
#  nan: <sfe.Node at 0x7f3f72b09510>,
#  nan: <sfe.Node at 0x7f3f6e8387d0>,
#  '19944,concept:musician:bach,concept:musicianplaysinstrument,concept:musicinstrument:harpsichord': <sfe.Node at 0x7f3f706f8b10>,
#  nan: <sfe.Node at 0x7f3f72034c90>,
#  nan: <sfe.Node at 0x7f3f7195c190>,
#  nan: <sfe.Node at 0x7f3f709c6dd0>,
#  nan: <sfe.Node at 0x7f3f6f580190>,
#  '7771,concept:ceo:abigail_johnson,concept:topmemberoforganization,concept:company:fmr_corp_': <sfe.Node at 0x7f3f72cd3410>,
#  nan: <sfe.Node at 0x7f3f743616d0>,
#  '5437,concept:automobilemaker:honda,concept:automobilemakercardealersinstateorprovince,concept:stateorprovince:ohio': <sfe.Node at 0x7f3f7332c290>,
#  nan: <sfe.Node at 0x7f3f6f05bf10>,
#  '10294,concept:city:homestead,concept:atlocation,concept:stateorprovince:florida': <sfe.Node at 0x7f3f72585590>,
#  nan: <sfe.Node at 0x7f3f74413090>,
#  nan: <sfe.Node at 0x7f3f73052a10>,
#  '25968,concept:sportsteam:boston_bruins,concept:teamhomestadium,concept:stadiumoreventvenue:td_garden': <sfe.Node at 0x7f3f6f5a5ed0>,
#  nan: <sfe.Node at 0x7f3f6e999b50>,
#  nan: <sfe.Node at 0x7f3f7085aed0>,
#  '4031,concept:athlete:kurt_busch,concept:athleteplayssportsteamposition,concept:sportsteamposition:right_center': <sfe.Node at 0x7f3f73830850>,
#  nan: <sfe.Node at 0x7f3f741cf410>,
#  nan: <sfe.Node at 0x7f3f72f20fd0>,
#  nan: <sfe.Node at 0x7f3f702d6810>,
#  nan: <sfe.Node at 0x7f3f708fd6d0>,
#  nan: <sfe.Node at 0x7f3f71e52490>,
#  '27,concept:academicfield:biology,concept:academicfieldsuchasacademicfield,concept:academicfield:physiology': <sfe.Node at 0x7f3f742ec790>,
#  nan: <sfe.Node at 0x7f3f6dca38d0>,
#  nan: <sfe.Node at 0x7f3f6db07310>,
#  '19169,concept:mammal:mountain_lions,concept:mammalsuchasmammal,concept:mammal:sheep': <sfe.Node at 0x7f3f708d0190>,
#  nan: <sfe.Node at 0x7f3f6ea62550>,
#  nan: <sfe.Node at 0x7f3f713d8650>,
#  '11312,concept:city:springfield,concept:atlocation,concept:stateorprovince:virginia': <sfe.Node at 0x7f3f71f55a90>,
#  '9188,concept:televisionstation:kbtv,concept:subpartoforganization,concept:company:nbc,1': <sfe.Node at 0x7f3f6da03d10>,
#  nan: <sfe.Node at 0x7f3f6df1fb50>,
#  nan: <sfe.Node at 0x7f3f735d6350>,
#  nan: <sfe.Node at 0x7f3f731eead0>,
#  '15406,concept:food:breast,concept:fooddecreasestheriskofdisease,concept:disease:problems': <sfe.Node at 0x7f3f71405a10>,
#  '15970,concept:furniture:bed,concept:furniturefoundinroom,concept:room:two_bedroom_units': <sfe.Node at 0x7f3f71224890>,
#  '7471,concept:building:the_mirage,concept:buildinglocatedincity,concept:city:los_angeles': <sfe.Node at 0x7f3f72d6db90>,
#  nan: <sfe.Node at 0x7f3f6d960b50>,
#  '4596,concept:country:u__s,concept:countryalsoknownas,concept:country:venezuela,1': <sfe.Node at 0x7f3f6e074ed0>,
#  '183,concept:academicfield:physical_therapy,concept:academicprogramatuniversity,concept:university:northeastern_university': <sfe.Node at 0x7f3f743ef6d0>,
#  '20147,concept:musician:keith_richards,concept:musicianplaysinstrument,concept:musicinstrument:guitar': <sfe.Node at 0x7f3f70619250>,
#  nan: <sfe.Node at 0x7f3f7081e190>,
#  '9229,concept:chemical:volatile_organic_compounds,concept:chemicalistypeofchemical,concept:chemical:emissions': <sfe.Node at 0x7f3f72876890>,
#  nan: <sfe.Node at 0x7f3f6ff330d0>,
#  '19854,concept:musicartist:season,concept:organizationhiredperson,concept:director:meyer': <sfe.Node at 0x7f3f70733d50>,
#  nan: <sfe.Node at 0x7f3f7104ce50>,
#  '10824,concept:city:new_britain,concept:locationlocatedwithinlocation,concept:beach:connecticut': <sfe.Node at 0x7f3f7240c2d0>,
#  nan: <sfe.Node at 0x7f3f6f5a5f90>,
#  nan: <sfe.Node at 0x7f3f6e66e4d0>,
#  '5597,concept:automobilemaker:mitsubishi,concept:hasofficeincountry,concept:country:uk': <sfe.Node at 0x7f3f7331f3d0>,
#  '17968,concept:journalist:seymour_hersh,concept:journalistwritesforpublication,concept:blog:new_yorker_magazine': <sfe.Node at 0x7f3f70ccef50>,
#  '24518,concept:professor:brad,concept:persongraduatedschool,concept:university:state_university': <sfe.Node at 0x7f3f6fa01e50>,
#  '31079,concept:winery:hartford,concept:subpartof,concept:beach:connecticut': <sfe.Node at 0x7f3f6e74d310>,
#  nan: <sfe.Node at 0x7f3f7425c850>,
#  '14085,concept:country:cayman_islands,concept:countrycurrency,concept:currency:dollars': <sfe.Node at 0x7f3f717beb10>,
#  '23110,concept:politician:alex_sink,concept:personleadsorganization,concept:stateorprovince:florida': <sfe.Node at 0x7f3f6fe0d350>,
#  '3656,concept:city:wilmington,concept:citylocatedinstate,concept:stateorprovince:nc,1': <sfe.Node at 0x7f3f6e1b1050>,
#  '6529,concept:beverage:sugar,concept:foodcancausedisease,concept:disease:acne': <sfe.Node at 0x7f3f7303ad10>,
#  '28281,concept:stadiumoreventvenue:pepsi_center,concept:stadiumlocatedincity,concept:city:denver': <sfe.Node at 0x7f3f6ef4c5d0>,
#  '11527,concept:city:washington_d_c_,concept:citylocatedincountry,concept:country:us_canada': <sfe.Node at 0x7f3f71ef67d0>,
#  nan: <sfe.Node at 0x7f3f6f15e050>,
#  nan: <sfe.Node at 0x7f3f73edde90>,
#  '1904,concept:animal:pups,concept:animalpreyson,concept:mammal:dog': <sfe.Node at 0x7f3f73e51110>,
#  nan: <sfe.Node at 0x7f3f72b09290>,
#  nan: <sfe.Node at 0x7f3f6dee4d10>,
#  '21868,concept:person:steven001,concept:topmemberoforganization,concept:biotechcompany:apple': <sfe.Node at 0x7f3f70174c50>,
#  '8925,concept:chemical:natural_gas,concept:chemicalistypeofchemical,concept:chemical:oil': <sfe.Node at 0x7f3f72990e10>,
#  '17378,concept:insect:small_insects,concept:animalsuchasinvertebrate,concept:insect:flies': <sfe.Node at 0x7f3f70e303d0>,
#  nan: <sfe.Node at 0x7f3f73bbee90>,
#  '12856,concept:coach:les_miles,concept:worksfor,concept:sportsteam:tigers': <sfe.Node at 0x7f3f71b3dad0>,
#  '23533,concept:politicianus:charles_schumer,concept:politicianholdsoffice,concept:politicaloffice:senator': <sfe.Node at 0x7f3f6fcb8a10>,
#  '10397,concept:city:kansas,concept:cityliesonriver,concept:river:grand': <sfe.Node at 0x7f3f7254a9d0>,
#  '9064,concept:chemical:particulate,concept:chemicalistypeofchemical,concept:chemical:emissions': <sfe.Node at 0x7f3f729034d0>,
#  '30306,concept:visualartist:mark_rothko,concept:visualartistartform,concept:visualartform:paintings': <sfe.Node at 0x7f3f6e98da50>,
#  '10492,concept:city:laredo,concept:atlocation,concept:stateorprovince:texas': <sfe.Node at 0x7f3f7250fa10>,
#  nan: <sfe.Node at 0x7f3f73a28ed0>,
#  '24443,concept:politicsblog:wtlv,concept:subpartoforganization,concept:company:nbc': <sfe.Node at 0x7f3f6f9d4850>,
#  '6620,concept:beverage:wines,concept:beveragemadefrombeverage,concept:wine:syrah': <sfe.Node at 0x7f3f72fffb50>,
#  nan: <sfe.Node at 0x7f3f6f889250>,
#  '6868,concept:person:mike001,concept:personborninlocation,concept:airport:jersey,1': <sfe.Node at 0x7f3f6dd30fd0>,
#  nan: <sfe.Node at 0x7f3f72b09490>,
#  '10512,concept:city:lebanon,concept:atlocation,concept:stateorprovince:indiana': <sfe.Node at 0x7f3f724a6450>,
#  '2888,concept:chemical:nitrous_oxide,concept:chemicalistypeofchemical,concept:chemical:chemicals,1': <sfe.Node at 0x7f3f6e306d10>,
#  nan: <sfe.Node at 0x7f3f6da28250>,
#  '3636,concept:athlete:jason_marquis,concept:athleteplaysforteam,concept:sportsteam:chicago_blackhawks': <sfe.Node at 0x7f3f73985f90>,
#  nan: <sfe.Node at 0x7f3f70a25f10>,
#  '16642,concept:furniture:futon,concept:furniturefoundinroom,concept:room:sunroom': <sfe.Node at 0x7f3f71087dd0>,
#  '21692,concept:person:richard_clark,concept:personleadsorganization,concept:biotechcompany:merck': <sfe.Node at 0x7f3f70201310>,
#  '17518,concept:invertebrate:worms,concept:animalsuchasinvertebrate,concept:arthropod:small_invertebrates': <sfe.Node at 0x7f3f70e0bad0>,
#  nan: <sfe.Node at 0x7f3f6fa01e10>,
#  '4843,concept:athlete:steve,concept:athleteinjuredhisbodypart,concept:artery:arm': <sfe.Node at 0x7f3f734f74d0>,
#  '7004,concept:bodypart:heart,concept:bodypartcontainsbodypart,concept:artery:pulmonary_artery': <sfe.Node at 0x7f3f72f14e50>,
#  nan: <sfe.Node at 0x7f3f72d84c10>,
#  '134,concept:academicfield:engineering,concept:academicprogramatuniversity,concept:university:clemson': <sfe.Node at 0x7f3f743c0dd0>,
#  nan: <sfe.Node at 0x7f3f70ef7f10>,
#  '16758,concept:furniture:sleeper_couch,concept:furniturefoundinroom,concept:room:living_room': <sfe.Node at 0x7f3f70fe38d0>,
#  nan: <sfe.Node at 0x7f3f71a99990>,
#  nan: <sfe.Node at 0x7f3f719217d0>,
#  '11610,concept:city:yonkers,concept:atlocation,concept:stateorprovince:new_york_city': <sfe.Node at 0x7f3f71ebb210>,
#  '385,concept:academicfield:technology,concept:academicfieldsuchasacademicfield,concept:academicfield:electronics': <sfe.Node at 0x7f3f74378d50>,
#  nan: <sfe.Node at 0x7f3f701afed0>,
#  '29869,concept:vegetable:pepper,concept:agriculturalproductcookedwithagriculturalproduct,concept:beverage:apple_cider_vinegar': <sfe.Node at 0x7f3f6eacac50>,
#  nan: <sfe.Node at 0x7f3f6ec51b90>,
#  '7329,concept:book:tale,concept:bookwriter,concept:writer:shakespeare': <sfe.Node at 0x7f3f72e10390>,
#  nan: <sfe.Node at 0x7f3f7345d910>,
#  '1198,concept:athlete:jeff_nelson,concept:athleteplaysinleague,concept:sportsleague:mlb,1': <sfe.Node at 0x7f3f6e519fd0>,
#  nan: <sfe.Node at 0x7f3f7291a9d0>,
#  nan: <sfe.Node at 0x7f3f6f3b6e50>,
#  nan: <sfe.Node at 0x7f3f6f95e910>,
#  nan: <sfe.Node at 0x7f3f7039d610>,
#  '20205,concept:musician:paul,concept:musicianplaysinstrument,concept:musicinstrument:guitars': <sfe.Node at 0x7f3f70630f90>,
#  nan: <sfe.Node at 0x7f3f719e8550>,
#  '14567,concept:criminal:lee_harvey_oswald,concept:hasbrother,concept:male:jfk': <sfe.Node at 0x7f3f71618fd0>,
#  '14352,concept:country:u__s,concept:countryalsoknownas,concept:country:syria': <sfe.Node at 0x7f3f7170e2d0>,
#  '10001,concept:city:evanston,concept:atlocation,concept:stateorprovince:wyoming': <sfe.Node at 0x7f3f726350d0>,
#  '26081,concept:sportsteam:cal_state_stanislaus_warriors,concept:subpartoforganization,concept:sportsteam:ncaa': <sfe.Node at 0x7f3f6f580850>,
#  nan: <sfe.Node at 0x7f3f736c1ed0>,
#  nan: <sfe.Node at 0x7f3f7283ba10>,
#  nan: <sfe.Node at 0x7f3f72d32090>,
#  '8317,concept:chemical:alcohol,concept:chemicalistypeofchemical,concept:chemical:water': <sfe.Node at 0x7f3f72b5a950>,
#  '9384,concept:city:anaheim,concept:locationlocatedwithinlocation,concept:stateorprovince:california': <sfe.Node at 0x7f3f727e9750>,
#  nan: <sfe.Node at 0x7f3f7364b450>,
#  '25290,concept:sport:golf,concept:sportschoolincountry,concept:country:taiwan': <sfe.Node at 0x7f3f6f7c1690>,
#  nan: <sfe.Node at 0x7f3f73d72690>,
#  '27513,concept:sportsteam:red_wings,concept:teamplaysincity,concept:city:detroit': <sfe.Node at 0x7f3f6f18cf90>,
#  '6150,concept:bank:chase,concept:acquired,concept:bank:wamu': <sfe.Node at 0x7f3f73127c90>,
#  nan: <sfe.Node at 0x7f3f7160b0d0>,
#  nan: <sfe.Node at 0x7f3f6eb7ca50>,
#  nan: <sfe.Node at 0x7f3f6f2eded0>,
#  '942,concept:athlete:brett_favre,concept:athleteplayssport,concept:sport:football,1': <sfe.Node at 0x7f3f6e5bded0>,
#  '18391,concept:language:russian,concept:languageofcountry,concept:country:u__s': <sfe.Node at 0x7f3f70b10650>,
#  '18358,concept:language:mandarin_chinese,concept:languageofcountry,concept:country:china': <sfe.Node at 0x7f3f70b79590>,
#  '19223,concept:mammal:ponies,concept:animalistypeofanimal,concept:mammal:pets': <sfe.Node at 0x7f3f708e6cd0>,
#  '24198,concept:politicianus:president_george_h__w__bush,concept:haswife,concept:female:barbara_bush': <sfe.Node at 0x7f3f6fa9bbd0>,
#  nan: <sfe.Node at 0x7f3f723a29d0>,
#  '22485,concept:personmexico:willie_bloomquist,concept:athleteplaysinleague,concept:sportsleague:mlb': <sfe.Node at 0x7f3f6ffc05d0>,
#  nan: <sfe.Node at 0x7f3f6f39fb90>,
#  nan: <sfe.Node at 0x7f3f6f76f4d0>,
#  '23371,concept:politicianus:barack,concept:politicianholdsoffice,concept:politicaloffice:first_president': <sfe.Node at 0x7f3f6fd457d0>,
#  '29273,concept:televisionstation:wfor,concept:subpartoforganization,concept:televisionnetwork:cbs': <sfe.Node at 0x7f3f6ec15d90>,
#  nan: <sfe.Node at 0x7f3f6e0ea610>,
#  '16895,concept:furniture:washbasins,concept:furniturefoundinroom,concept:room:bathrooms': <sfe.Node at 0x7f3f70fbfe50>,
#  nan: <sfe.Node at 0x7f3f740a8e50>,
#  '2469,concept:arthropod:seafood,concept:arthropodcalledarthropod,concept:crustacean:lobsters': <sfe.Node at 0x7f3f73cd8fd0>,
#  '8812,concept:sportsteam:red_sox,concept:teamalsoknownas,concept:sportsteam:chicago_blackhawks,1': <sfe.Node at 0x7f3f6da7ad90>,
#  '19575,concept:muscle:skeletal_muscles,concept:bodypartcontainsbodypart,concept:bodypart:system': <sfe.Node at 0x7f3f707e3f90>,
#  '16315,concept:furniture:beds,concept:furniturefoundinroom,concept:room:extra_bedroom': <sfe.Node at 0x7f3f711217d0>,
#  '12733,concept:coach:harbaugh,concept:worksfor,concept:sportsteam:baltimore_ravens': <sfe.Node at 0x7f3f71b61c50>,
#  '3480,concept:athlete:hal_morris,concept:athleteplaysinleague,concept:sportsleague:mlb': <sfe.Node at 0x7f3f73a28090>,
#  '13248,concept:company:boston_globe001,concept:headquarteredin,concept:city:new_york_city': <sfe.Node at 0x7f3f719e8210>,
#  nan: <sfe.Node at 0x7f3f73d4dd10>,
#  nan: <sfe.Node at 0x7f3f727e9790>,
#  nan: <sfe.Node at 0x7f3f6ed46e90>,
#  nan: <sfe.Node at 0x7f3f6f8aced0>,
#  '29998,concept:vegetable:potato,concept:vegetableproductioninstateorprovince,concept:stateorprovince:wisconsin': <sfe.Node at 0x7f3f6ea27dd0>,
#  '12235,concept:clothing:skirts,concept:clothingtogowithclothing,concept:clothing:shirts': <sfe.Node at 0x7f3f71cf1f50>,
#  '10561,concept:city:lompoc,concept:subpartof,concept:stateorprovince:california': <sfe.Node at 0x7f3f724bcd10>,
#  nan: <sfe.Node at 0x7f3f73e51450>,
#  nan: <sfe.Node at 0x7f3f6ffe4a90>,
#  '20979,concept:person:frederick,concept:personhascitizenship,concept:country:saxony': <sfe.Node at 0x7f3f703ef8d0>,
#  '21200,concept:person:john,concept:worksfor,concept:company:the_new_york_times001': <sfe.Node at 0x7f3f70311910>,
#  nan: <sfe.Node at 0x7f3f6f42cf50>,
#  nan: <sfe.Node at 0x7f3f6eca2710>,
#  nan: <sfe.Node at 0x7f3f709ea450>,
#  nan: <sfe.Node at 0x7f3f6e5a50d0>,
#  nan: <sfe.Node at 0x7f3f70d2cfd0>,
#  '7048,concept:personmexico:adam_loewen,concept:athleteplayssport,concept:sport:baseball,1': <sfe.Node at 0x7f3f6dcf5d90>,
#  nan: <sfe.Node at 0x7f3f71c12bd0>,
#  nan: <sfe.Node at 0x7f3f6f1b0650>,
#  nan: <sfe.Node at 0x7f3f7060c8d0>,
#  '17197,concept:insect:brown_recluse,concept:arthropodandotherarthropod,concept:arthropod:spider_bite': <sfe.Node at 0x7f3f70ea57d0>,
#  nan: <sfe.Node at 0x7f3f704b7990>,
#  nan: <sfe.Node at 0x7f3f6f734910>,
#  '8607,concept:chemical:dioxide,concept:chemicalistypeofchemical,concept:chemical:toxic_chemicals': <sfe.Node at 0x7f3f72a2ac90>,
#  nan: <sfe.Node at 0x7f3f6ef1df90>,
#  nan: <sfe.Node at 0x7f3f72fe8ed0>,
#  '20666,concept:person:brad_grey,concept:topmemberoforganization,concept:recordlabel:paramount_pictures': <sfe.Node at 0x7f3f705099d0>,
#  nan: <sfe.Node at 0x7f3f6ed0b3d0>,
#  '28235,concept:stadiumoreventvenue:fillmore,concept:stadiumlocatedincity,concept:city:denver': <sfe.Node at 0x7f3f6ef1de50>,
#  '10025,concept:city:fishers,concept:atlocation,concept:stateorprovince:indiana': <sfe.Node at 0x7f3f72635cd0>,
#  '9252,concept:televisionstation:kpic,concept:subpartoforganization,concept:televisionnetwork:cbs,1': <sfe.Node at 0x7f3f6d99bd50>,
#  '8289,concept:chef:kalle_lasn,concept:personbelongstoorganization,concept:publication:adbusters': <sfe.Node at 0x7f3f72b44b10>,
#  '24563,concept:protein:laboratories,concept:subpartof,concept:weatherphenomenon:water': <sfe.Node at 0x7f3f6f9af550>,
#  '9458,concept:city:atlanta,concept:citylocatedincountry,concept:country:us_canada': <sfe.Node at 0x7f3f72817cd0>,
#  nan: <sfe.Node at 0x7f3f6e691750>,
#  nan: <sfe.Node at 0x7f3f73b2bd90>,
#  '24693,concept:recordlabel:royal,concept:hasofficeincountry,concept:country:nz': <sfe.Node at 0x7f3f6f98b750>,
#  '6146,concept:bank:blackstone_group,concept:companyeconomicsector,concept:economicsector:equity': <sfe.Node at 0x7f3f73127a90>,
#  '24641,concept:radiostation:ut,concept:organizationhiredperson,concept:person:lane_kiffin': <sfe.Node at 0x7f3f6f95ecd0>,
#  '18319,concept:language:japanese,concept:languageofcountry,concept:country:japan': <sfe.Node at 0x7f3f70b621d0>,
#  '9670,concept:visualartist:john_singer_sargent,concept:visualartistartform,concept:visualartform:paintings,1': <sfe.Node at 0x7f3f6d93c790>,
#  '22409,concept:personmexico:matt_kemp,concept:athleteplayssport,concept:sport:baseball': <sfe.Node at 0x7f3f6fffbf10>,
#  '3572,concept:city:sioux_city,concept:locationlocatedwithinlocation,concept:stateorprovince:iowa,1': <sfe.Node at 0x7f3f6e203ad0>,
#  '23481,concept:politicianus:bush,concept:politicianusendorsedbypoliticianus,concept:politicianus:richard_nixon': <sfe.Node at 0x7f3f6fd0af90>,
#  '22177,concept:personeurope:john,concept:journalistwritesforpublication,concept:publication:nyt': <sfe.Node at 0x7f3f7005a950>,
#  nan: <sfe.Node at 0x7f3f71d2c950>,
#  nan: <sfe.Node at 0x7f3f6de57450>,
#  nan: <sfe.Node at 0x7f3f70466790>,
#  '885,concept:agriculturalproduct:herbs,concept:agriculturalproducttoattractinsect,concept:arthropod:beneficial_insects': <sfe.Node at 0x7f3f74158b50>,
#  nan: <sfe.Node at 0x7f3f6da62190>,
#  nan: <sfe.Node at 0x7f3f70201f50>,
#  nan: <sfe.Node at 0x7f3f70e54f90>,
#  '27265,concept:sportsteam:oakland_raiders,concept:teamplayssport,concept:sport:football': <sfe.Node at 0x7f3f6f1eb1d0>,
#  '3162,concept:athlete:david_eckstein,concept:athleteplaysinleague,concept:sportsleague:nfl': <sfe.Node at 0x7f3f73b2bed0>,
#  '18532,concept:male:cecil_fielder,concept:fatherofperson,concept:personus:prince_fielder': <sfe.Node at 0x7f3f70aecdd0>,
#  '7109,concept:bodypart:system,concept:bodypartcontainsbodypart,concept:lymphnode:lymph_system': <sfe.Node at 0x7f3f72e6f3d0>,
#  nan: <sfe.Node at 0x7f3f72acef50>,
#  '1600,concept:animal:cat001,concept:animalpreyson,concept:animal:animals001': <sfe.Node at 0x7f3f73f6b690>,
#  nan: <sfe.Node at 0x7f3f73b66ad0>,
#  '2044,concept:beverage:caffeine,concept:foodcancausedisease,concept:physiologicalcondition:blood_pressure,1': <sfe.Node at 0x7f3f6e3db6d0>,
#  nan: <sfe.Node at 0x7f3f6e3b6110>,
#  '6807,concept:bird:larger_birds,concept:animalistypeofanimal,concept:mammal:predators': <sfe.Node at 0x7f3f72f89a50>,
#  nan: <sfe.Node at 0x7f3f70f328d0>,
#  nan: <sfe.Node at 0x7f3f71858f50>,
#  '5342,concept:furniture:futons,concept:furniturefoundinroom,concept:room:living_room,1': <sfe.Node at 0x7f3f6df87c50>,
#  '15802,concept:furniture:basins,concept:furniturefoundinroom,concept:room:bathroom': <sfe.Node at 0x7f3f712b0350>,
#  '15673,concept:food:peppers,concept:agriculturalproductcookedwithagriculturalproduct,concept:legume:black_beans': <sfe.Node at 0x7f3f712d41d0>,
#  nan: <sfe.Node at 0x7f3f6ede0a90>,
#  nan: <sfe.Node at 0x7f3f6f8899d0>,
#  nan: <sfe.Node at 0x7f3f71b9c7d0>,
#  '6698,concept:biotechcompany:microsoft__,concept:producesproduct,concept:software:outlook': <sfe.Node at 0x7f3f72fc4310>,
#  nan: <sfe.Node at 0x7f3f72dd5c10>,
#  '3234,concept:athlete:dirk_nowitzki,concept:athleteplaysforteam,concept:sportsteam:dallas_mavericks': <sfe.Node at 0x7f3f73a71390>,
#  nan: <sfe.Node at 0x7f3f73052790>,
#  nan: <sfe.Node at 0x7f3f742ad550>,
#  nan: <sfe.Node at 0x7f3f71645090>,
#  '10330,concept:city:inglewood,concept:subpartof,concept:stateorprovince:california': <sfe.Node at 0x7f3f7259b7d0>,
#  '12922,concept:coach:pat_riley,concept:coachesinleague,concept:sportsleague:nba': <sfe.Node at 0x7f3f71aebc50>,
#  nan: <sfe.Node at 0x7f3f71c28990>,
#  nan: <sfe.Node at 0x7f3f71b9c450>,
#  '25657,concept:sportsgame:n1983_world_series,concept:sportsgameteam,concept:sportsteam:philadelphia_phillies': <sfe.Node at 0x7f3f6f655110>,
#  '10369,concept:city:jennings,concept:citylocatedinstate,concept:stateorprovince:indiana': <sfe.Node at 0x7f3f72532b90>,
#  '5640,concept:journalist:bud_shaw,concept:journalistwritesforpublication,concept:website:cleveland_plain_dealer,1': <sfe.Node at 0x7f3f6defb810>,
#  nan: <sfe.Node at 0x7f3f6dad8310>,
#  nan: <sfe.Node at 0x7f3f72c46810>,
#  '7516,concept:buildingfeature:doors,concept:buildingfeaturemadefrombuildingmaterial,concept:visualizablething:silver': <sfe.Node at 0x7f3f72d9b290>,
#  nan: <sfe.Node at 0x7f3f723f50d0>,
#  nan: <sfe.Node at 0x7f3f7327a610>,
#  nan: <sfe.Node at 0x7f3f70b79750>,
#  nan: <sfe.Node at 0x7f3f703efe90>,
#  '24104,concept:politicianus:nancy_pelosi,concept:politicianusmemberofpoliticalgroup,concept:organization:senate': <sfe.Node at 0x7f3f6fad6c10>,
#  '363,concept:academicfield:system,concept:subpartof,concept:hallwayitem:liquid': <sfe.Node at 0x7f3f74378250>,
#  '13851,concept:company:the_guardian001,concept:headquarteredin,concept:city:new_york_city': <sfe.Node at 0x7f3f7181d450>,
#  nan: <sfe.Node at 0x7f3f6da62390>,
#  '23377,concept:politicianus:barack_obama,concept:politicianholdsoffice,concept:politicaloffice:u_s__senators': <sfe.Node at 0x7f3f6fd45ad0>,
#  nan: <sfe.Node at 0x7f3f70921ed0>,
#  '22431,concept:personmexico:mike_krzyzewski,concept:personbelongstoorganization,concept:university:duke_university': <sfe.Node at 0x7f3f6ff92a50>,
#  nan: <sfe.Node at 0x7f3f72903290>,
#  nan: <sfe.Node at 0x7f3f70d09050>,
#  '27600,concept:sportsteam:san_diego_toreros,concept:teamplaysinleague,concept:sportsleague:ncaa': <sfe.Node at 0x7f3f6f0d1bd0>,
#  nan: <sfe.Node at 0x7f3f728b1710>,
#  nan: <sfe.Node at 0x7f3f73634c10>,
#  nan: <sfe.Node at 0x7f3f72a64790>,
#  '8170,concept:sport:volleyball,concept:sportusesequipment,concept:sportsequipment:equipment,1': <sfe.Node at 0x7f3f6db13a90>,
#  '25634,concept:sportsgame:n1945_world_series,concept:sportsgamewinner,concept:sportsteam:detroit_tigers': <sfe.Node at 0x7f3f6f6be550>,
#  nan: <sfe.Node at 0x7f3f72430590>,
#  '13743,concept:company:ryan_air,concept:headquarteredin,concept:city:heathrow': <sfe.Node at 0x7f3f718c2d50>,
#  nan: <sfe.Node at 0x7f3f71405850>,
#  '20337,concept:nerve:peripheral_nerves,concept:bodypartcontainsbodypart,concept:bodypart:cord001': <sfe.Node at 0x7f3f705a32d0>,
#  nan: <sfe.Node at 0x7f3f72086c90>,
#  '5340,concept:furniture:futons,concept:furniturefoundinroom,concept:room:loft,1': <sfe.Node at 0x7f3f6df87bd0>,
#  '8920,concept:sportsteam:trail_blazers,concept:teamalsoknownas,concept:sportsteam:phoenix_suns,1': <sfe.Node at 0x7f3f6da28910>,
#  '11112,concept:city:resources,concept:subpartoforganization,concept:governmentorganization:federal_government': <sfe.Node at 0x7f3f7204b510>,
#  '1974,concept:bank:citigroup,concept:companyeconomicsector,concept:economicsector:financial_services,1': <sfe.Node at 0x7f3f6e444510>,
#  '2796,concept:athlete:brad_ziegler,concept:athleteplayssport,concept:sport:baseball': <sfe.Node at 0x7f3f73bd5610>,
#  '12955,concept:coach:rich_rodriguez,concept:personbelongstoorganization,concept:stateorprovince:michigan': <sfe.Node at 0x7f3f71b02d10>,
#  '3246,concept:city:greeley,concept:subpartof,concept:stateorprovince:colorado,1': <sfe.Node at 0x7f3f6e210810>,
#  nan: <sfe.Node at 0x7f3f72ce0410>,
#  nan: <sfe.Node at 0x7f3f71405a50>,
#  nan: <sfe.Node at 0x7f3f739fbd50>,
#  '17294,concept:insect:garden_pests,concept:animalsuchasinvertebrate,concept:invertebrate:slugs': <sfe.Node at 0x7f3f70e6a910>,
#  '2798,concept:athlete:brandon_backe,concept:athleteplaysforteam,concept:sportsteam:astros': <sfe.Node at 0x7f3f73bd5710>,
#  nan: <sfe.Node at 0x7f3f73d29e10>,
#  nan: <sfe.Node at 0x7f3f74056bd0>,
#  '30065,concept:vehicle:needs,concept:subpartof,concept:physiologicalcondition:water_supply': <sfe.Node at 0x7f3f6e9d4fd0>,
#  nan: <sfe.Node at 0x7f3f6d9c8b10>,
#  '23876,concept:politicianus:john_adams,concept:politicianusholdsoffice,concept:jobposition:secretary': <sfe.Node at 0x7f3f6fbb5850>,
#  '7074,concept:personmexico:jason_bartlett,concept:athleteplaysforteam,concept:sportsteam:tampa_bay_devil_rays,1': <sfe.Node at 0x7f3f6dd0c450>,
#  '24348,concept:politicianus:senator_mccain,concept:politicianusendorsedbypoliticianus,concept:female:sarah_palin': <sfe.Node at 0x7f3f6fa8f810>,
#  nan: <sfe.Node at 0x7f3f713d8b50>,
#  nan: <sfe.Node at 0x7f3f6e9d4890>,
#  nan: <sfe.Node at 0x7f3f70568d50>,
#  '25618,concept:sportsgame:euro_2000,concept:sportsgameteam,concept:sportsteam:france': <sfe.Node at 0x7f3f6f6a7d10>,
#  nan: <sfe.Node at 0x7f3f6e450a90>,
#  '16587,concept:furniture:couch,concept:furniturefoundinroom,concept:room:suite': <sfe.Node at 0x7f3f71070210>,
#  nan: <sfe.Node at 0x7f3f6e42d810>,
#  '20486,concept:nut:pine_nuts,concept:agriculturalproductcookedwithagriculturalproduct,concept:vegetable:pepper': <sfe.Node at 0x7f3f7057fe50>,
#  '8359,concept:chemical:carbon,concept:chemicalistypeofchemical,concept:chemical:organic_matter': <sfe.Node at 0x7f3f72af1e90>,
#  '26253,concept:sportsteam:colonials,concept:subpartoforganization,concept:sportsteam:ncaa': <sfe.Node at 0x7f3f6f4f4f90>,
#  '29174,concept:televisionstation:wavy,concept:televisionstationaffiliatedwith,concept:televisionnetwork:nbc_universal': <sfe.Node at 0x7f3f6ec51b50>,
#  nan: <sfe.Node at 0x7f3f70682a50>,
#  '12015,concept:clothing:pants,concept:clothingtogowithclothing,concept:clothing:jerseys': <sfe.Node at 0x7f3f71d50f90>,
#  '4871,concept:athlete:ted_lilly,concept:athleteplayssport,concept:sport:baseball': <sfe.Node at 0x7f3f7350d310>,
#  '7020,concept:personcanada:paul_johnson,concept:worksfor,concept:sportsteam:west_georgia_technical_college,1': <sfe.Node at 0x7f3f6dcf5690>,
#  '3709,concept:athlete:jeremy_bonderman,concept:athleteplaysinleague,concept:sportsleague:mlb': <sfe.Node at 0x7f3f7394a4d0>,
#  '20943,concept:person:eric001,concept:personhascitizenship,concept:country:norway': <sfe.Node at 0x7f3f703d8690>,
#  '22165,concept:personeurope:brian_l__roberts,concept:worksfor,concept:company:comcast': <sfe.Node at 0x7f3f7005a350>,
#  nan: <sfe.Node at 0x7f3f6df87b90>,
#  '24973,concept:room:technology,concept:subpartof,concept:musicalbum:state_of_the_art': <sfe.Node at 0x7f3f6f85b590>,
#  nan: <sfe.Node at 0x7f3f6f407150>,
#  '5759,concept:awardtrophytournament:stanley_cup,concept:awardtrophytournamentisthechampionshipgameofthenationalsport,concept:sport:hockey': <sfe.Node at 0x7f3f73292610>,
#  '7237,concept:book:hobbit,concept:bookwriter,concept:writer:tolkien': <sfe.Node at 0x7f3f72e4b4d0>,
#  '5595,concept:automobilemaker:mitsubishi,concept:hasofficeincountry,concept:country:america': <sfe.Node at 0x7f3f7331f2d0>,
#  '11819,concept:clothing:dresses,concept:clothingtogowithclothing,concept:clothing:skirts': <sfe.Node at 0x7f3f71e46c10>,
#  '9807,concept:city:co,concept:locationlocatedwithinlocation,concept:country:us_canada': <sfe.Node at 0x7f3f72714e10>,
#  nan: <sfe.Node at 0x7f3f702017d0>,
#  nan: <sfe.Node at 0x7f3f73eddf90>,
#  nan: <sfe.Node at 0x7f3f70e6ac50>,
#  nan: <sfe.Node at 0x7f3f71f48710>,
#  '1762,concept:automobilemaker:jeep,concept:automobilemakercardealersinstateorprovince,concept:stateorprovince:delaware,1': <sfe.Node at 0x7f3f6e468f10>,
#  '23866,concept:politicianus:john,concept:politicianusholdsoffice,concept:politicaloffice:great_president': <sfe.Node at 0x7f3f6fbb5350>,
#  '30619,concept:weapon:arms,concept:weaponmadeincountry,concept:country:kosovo': <sfe.Node at 0x7f3f6e873950>,
#  '18719,concept:mammal:bear,concept:mammalsuchasmammal,concept:mammal:caribou': <sfe.Node at 0x7f3f70a76cd0>,
#  nan: <sfe.Node at 0x7f3f6ee83310>,
#  '22841,concept:plant:ponderosa,concept:plantincludeplant,concept:plant:trees': <sfe.Node at 0x7f3f6febea90>,
#  nan: <sfe.Node at 0x7f3f73359c50>,
#  nan: <sfe.Node at 0x7f3f7278acd0>,
#  '11790,concept:clothing:dress,concept:clothingtogowithclothing,concept:clothing:shirts': <sfe.Node at 0x7f3f71e2ed50>,
#  nan: <sfe.Node at 0x7f3f6e85c450>,
#  '23499,concept:politicianus:bush,concept:politicianusendorsedbypoliticianus,concept:politicianus:bob_dole': <sfe.Node at 0x7f3f6fca08d0>,
#  '5794,concept:language:english,concept:languageofcountry,concept:country:puerto_rico,1': <sfe.Node at 0x7f3f6dea9f10>,
#  nan: <sfe.Node at 0x7f3f6e88a7d0>,
#  '2937,concept:athlete:chad_billingsley,concept:athleteplayssport,concept:sport:baseball': <sfe.Node at 0x7f3f747c9c90>,
#  nan: <sfe.Node at 0x7f3f70792f50>,
#  '4904,concept:fish:red_snapper,concept:fishservedwithfood,concept:condiment:butter_sauce,1': <sfe.Node at 0x7f3f6dfe6d10>,
#  nan: <sfe.Node at 0x7f3f6faeec10>,
#  nan: <sfe.Node at 0x7f3f71e2e290>,
#  '9011,concept:chemical:organic_material,concept:chemicalistypeofchemical,concept:chemical:carbon': <sfe.Node at 0x7f3f729559d0>,
#  nan: <sfe.Node at 0x7f3f709d2710>,
#  nan: <sfe.Node at 0x7f3f7194edd0>,
#  nan: <sfe.Node at 0x7f3f72dd5490>,
#  nan: <sfe.Node at 0x7f3f70619c90>,
#  nan: <sfe.Node at 0x7f3f73ceea50>,
#  nan: <sfe.Node at 0x7f3f74245910>,
#  '17227,concept:insect:bugs,concept:animalsuchasinsect,concept:insect:spider_mites': <sfe.Node at 0x7f3f70ebc710>,
#  nan: <sfe.Node at 0x7f3f7033e5d0>,
#  nan: <sfe.Node at 0x7f3f716534d0>,
#  '15366,concept:fish:walleye,concept:fishservedwithfood,concept:bakedgood:sauce': <sfe.Node at 0x7f3f713ee5d0>,
#  nan: <sfe.Node at 0x7f3f71887ad0>,
#  '4717,concept:athlete:s_k,concept:athletebeatathlete,concept:athlete:williams': <sfe.Node at 0x7f3f7359b4d0>,
#  nan: <sfe.Node at 0x7f3f6d8ea750>,
#  '1668,concept:automobilemaker:chevrolet,concept:automobilemakerdealersincity,concept:city:indianapolis,1': <sfe.Node at 0x7f3f6e450750>,
#  nan: <sfe.Node at 0x7f3f6fb11110>,
#  '3632,concept:athlete:jason_kidd,concept:athleteplayssport,concept:sport:basketball': <sfe.Node at 0x7f3f73985d90>,
#  nan: <sfe.Node at 0x7f3f70c65c50>,
#  nan: <sfe.Node at 0x7f3f6de6d110>,
#  '3924,concept:athlete:julio_franco,concept:athleteplaysinleague,concept:sportsleague:mlb': <sfe.Node at 0x7f3f738eb210>,
#  '8278,concept:charactertrait:analysis,concept:subpartof,concept:weatherphenomenon:air': <sfe.Node at 0x7f3f72b44590>,
#  '12601,concept:coach:brian_burres,concept:athleteplaysinleague,concept:sportsleague:mlb': <sfe.Node at 0x7f3f71c04950>,
#  '29110,concept:televisionstation:kwtx_tv,concept:televisionstationaffiliatedwith,concept:televisionnetwork:cbs': <sfe.Node at 0x7f3f6eca2ad0>,
#  '6886,concept:person:nan_wang,concept:personhasresidenceingeopoliticallocation,concept:country:china,1': <sfe.Node at 0x7f3f6dd47490>,
#  '26149,concept:sportsteam:charleston_cougars,concept:subpartoforganization,concept:sportsteam:ncaa': <sfe.Node at 0x7f3f6f52fad0>,
#  '21077,concept:person:hua_guofeng,concept:personleadsorganization,concept:organization:chinese': <sfe.Node at 0x7f3f703b4a90>,
#  nan: <sfe.Node at 0x7f3f6eebe150>,
#  nan: <sfe.Node at 0x7f3f6f8c4990>,
#  nan: <sfe.Node at 0x7f3f6e50b0d0>,
#  nan: <sfe.Node at 0x7f3f6e4f4f90>,
#  '345,concept:academicfield:system,concept:istallerthan,concept:magazine:people_': <sfe.Node at 0x7f3f74361910>,
#  nan: <sfe.Node at 0x7f3f735e2810>,
#  '18809,concept:mammal:chinchillas,concept:animalistypeofanimal,concept:animal:herbivores': <sfe.Node at 0x7f3f70a3ba90>,
#  nan: <sfe.Node at 0x7f3f7147b050>,
#  nan: <sfe.Node at 0x7f3f741f2d90>,
#  nan: <sfe.Node at 0x7f3f6ef70310>,
#  '2588,concept:ceo:sir_fred_goodwin,concept:personleadsorganization,concept:bank:royal_bank_of_scotland,1': <sfe.Node at 0x7f3f6e32a110>,
#  '17292,concept:insect:fruit_flies,concept:arthropodandotherarthropod,concept:arthropod:pests': <sfe.Node at 0x7f3f70e6a810>,
#  nan: <sfe.Node at 0x7f3f70551d90>,
#  '17353,concept:insect:mosquitoes,concept:animalsuchasinsect,concept:arthropod:pests': <sfe.Node at 0x7f3f70e19710>,
#  nan: <sfe.Node at 0x7f3f6fe6b850>,
#  nan: <sfe.Node at 0x7f3f71db8a10>,
#  '26793,concept:sportsteam:lambuth_eagles,concept:subpartoforganization,concept:sportsteam:ncaa': <sfe.Node at 0x7f3f6f312210>,
#  '2302,concept:arthropod:crustaceans,concept:arthropodcalledarthropod,concept:crustacean:krill': <sfe.Node at 0x7f3f73d65b10>,
#  nan: <sfe.Node at 0x7f3f708d08d0>,
#  '27817,concept:sportsteam:temple_owls,concept:subpartoforganization,concept:sportsteam:ncaa': <sfe.Node at 0x7f3f6f072a10>,
#  '2157,concept:artery:internal_organs,concept:bodypartcontainsbodypart,concept:artery:vessels': <sfe.Node at 0x7f3f73d88190>,
#  nan: <sfe.Node at 0x7f3f70ea5210>,
#  nan: <sfe.Node at 0x7f3f70e30f10>,
#  nan: <sfe.Node at 0x7f3f72d32410>,
#  '21675,concept:person:rauschenberg,concept:personbornincity,concept:city:york': <sfe.Node at 0x7f3f701eaa50>,
#  nan: <sfe.Node at 0x7f3f71beead0>,
#  nan: <sfe.Node at 0x7f3f708366d0>,
#  '13775,concept:company:samsung001,concept:hasofficeincountry,concept:country:south_korea': <sfe.Node at 0x7f3f71858d90>,
#  '22846,concept:plant:poplar,concept:plantincludeplant,concept:plant:tree_species': <sfe.Node at 0x7f3f6febed10>,
#  nan: <sfe.Node at 0x7f3f6e8ae950>,
#  nan: <sfe.Node at 0x7f3f70e0b290>,
#  nan: <sfe.Node at 0x7f3f6e6a8310>,
#  nan: <sfe.Node at 0x7f3f6e3b6e90>,
#  nan: <sfe.Node at 0x7f3f6dd1afd0>,
#  '6313,concept:bank:toronto_dominion_bank,concept:hasofficeincountry,concept:country:canada': <sfe.Node at 0x7f3f73119f50>,
#  '23513,concept:politicianus:bush,concept:politicianusendorsedbypoliticianus,concept:female:sarah_palin': <sfe.Node at 0x7f3f6fca0fd0>,
#  nan: <sfe.Node at 0x7f3f6ff4a590>,
#  nan: <sfe.Node at 0x7f3f6ea9dd90>,
#  nan: <sfe.Node at 0x7f3f6e821290>,
#  '17629,concept:journalist:bryan,concept:persongraduatedschool,concept:university:state_university': <sfe.Node at 0x7f3f70d67350>,
#  nan: <sfe.Node at 0x7f3f73830310>,
#  nan: <sfe.Node at 0x7f3f6df95c50>,
# ...
#  '20165,concept:musician:mendelssohn,concept:musicianplaysinstrument,concept:musicinstrument:piano': <sfe.Node at 0x7f3f70619b50>,
#  nan: <sfe.Node at 0x7f3f71791450>,
#  '15433,concept:food:cream,concept:agriculturalproductcutintogeometricshape,concept:geometricshape:piece': <sfe.Node at 0x7f3f7139d7d0>,
#  nan: <sfe.Node at 0x7f3f719c4a50>,
#  nan: <sfe.Node at 0x7f3f73b383d0>,
#  nan: <sfe.Node at 0x7f3f70f84ed0>,
#  nan: <sfe.Node at 0x7f3f70413b90>,
#  nan: <sfe.Node at 0x7f3f7240cb90>,
#  nan: <sfe.Node at 0x7f3f7403f390>,
#  '9629,concept:city:bronx,concept:subpartof,concept:company:new_york': <sfe.Node at 0x7f3f727213d0>,
#  nan: <sfe.Node at 0x7f3f70e190d0>,
#  nan: <sfe.Node at 0x7f3f6f98b190>,
#  '9451,concept:city:aswan,concept:citylocatedingeopoliticallocation,concept:country:egypt': <sfe.Node at 0x7f3f72817950>,
#  '14212,concept:country:moldova,concept:countryalsoknownas,concept:country:romania': <sfe.Node at 0x7f3f7171ab90>,
#  nan: <sfe.Node at 0x7f3f70b793d0>,
#  nan: <sfe.Node at 0x7f3f71bd7b90>,
#  '30497,concept:visualizableobject:shirt,concept:clothingtogowithclothing,concept:clothing:cargo_shorts': <sfe.Node at 0x7f3f6e897b50>,
#  '4806,concept:athlete:shelley_duncan,concept:athleteplayssport,concept:sport:baseball': <sfe.Node at 0x7f3f7355f210>,
#  '27603,concept:sportsteam:san_francisco_49ers,concept:teamhomestadium,concept:stadiumoreventvenue:candlestick_park': <sfe.Node at 0x7f3f6f0d1d50>,
#  '28303,concept:stadiumoreventvenue:skydome,concept:stadiumlocatedincity,concept:city:toronto': <sfe.Node at 0x7f3f6eee3110>,
#  nan: <sfe.Node at 0x7f3f6f60ddd0>,
#  '1828,concept:animal:marine_life,concept:animalsuchasfish,concept:fish:stingrays': <sfe.Node at 0x7f3f73e8ca50>,
#  nan: <sfe.Node at 0x7f3f712b0610>,
#  nan: <sfe.Node at 0x7f3f6e6a8490>,
#  '4695,concept:athlete:ryan_dempster,concept:athleteplaysinleague,concept:sportsleague:mlb': <sfe.Node at 0x7f3f73583990>,
#  '18247,concept:language:english_language,concept:languageschoolincity,concept:city:dublin': <sfe.Node at 0x7f3f70b9dd10>,
#  '18085,concept:language:english,concept:languageofcountry,concept:country:estonia': <sfe.Node at 0x7f3f70c2aad0>,
#  nan: <sfe.Node at 0x7f3f6f2260d0>,
#  nan: <sfe.Node at 0x7f3f706a6550>,
#  '22768,concept:plant:holm_oak,concept:plantincludeplant,concept:plant:trees': <sfe.Node at 0x7f3f6ff0f590>,
#  nan: <sfe.Node at 0x7f3f6eee3a50>,
#  '6976,concept:person:victoria,concept:personhasjobposition,concept:jobposition:queen,1': <sfe.Node at 0x7f3f6dcdeb50>,
#  nan: <sfe.Node at 0x7f3f6ef70410>,
#  '3631,concept:athlete:jason_kapono,concept:athleteplaysinleague,concept:sportsleague:nba': <sfe.Node at 0x7f3f73985d10>,
#  '30198,concept:visualartist:corot,concept:visualartistartform,concept:visualartform:collection': <sfe.Node at 0x7f3f6e9c8390>,
#  '11103,concept:city:redding,concept:atlocation,concept:stateorprovince:california': <sfe.Node at 0x7f3f7204b090>,
#  '12195,concept:clothing:shorts,concept:clothingtogowithclothing,concept:clothing:polo_shirt': <sfe.Node at 0x7f3f71cd9b10>,
#  nan: <sfe.Node at 0x7f3f7308d550>,
#  '11715,concept:clothing:blue_shorts,concept:clothingtogowithclothing,concept:visualizableobject:shirt': <sfe.Node at 0x7f3f71e80750>,
#  '13753,concept:company:ryanair,concept:hasofficeincity,concept:city:valencia': <sfe.Node at 0x7f3f71858290>,
#  nan: <sfe.Node at 0x7f3f6f4a1a50>,
#  nan: <sfe.Node at 0x7f3f72714750>,
#  '8017,concept:ceo:jonathan_schwartz,concept:topmemberoforganization,concept:newspaper:snow_country': <sfe.Node at 0x7f3f72c0b110>,
#  nan: <sfe.Node at 0x7f3f7250f6d0>,
#  '19229,concept:mammal:predators,concept:animalistypeofanimal,concept:mammal:cats': <sfe.Node at 0x7f3f708e6fd0>,
#  '46,concept:academicfield:christian_education,concept:academicprogramatuniversity,concept:university:theological_seminary': <sfe.Node at 0x7f3f74413150>,
#  nan: <sfe.Node at 0x7f3f6f340b50>,
#  nan: <sfe.Node at 0x7f3f6fdf5150>,
#  '16353,concept:furniture:beds,concept:furniturefoundinroom,concept:room:first_room': <sfe.Node at 0x7f3f71138b10>,
#  nan: <sfe.Node at 0x7f3f7318f310>,
#  '8309,concept:chemical:acids,concept:chemicalistypeofchemical,concept:chemical:carbon': <sfe.Node at 0x7f3f72b5a550>,
#  nan: <sfe.Node at 0x7f3f71a8c0d0>,
#  nan: <sfe.Node at 0x7f3f71121f90>,
#  nan: <sfe.Node at 0x7f3f70c2a310>,
#  '8050,concept:ceo:liu_chuanzhi,concept:worksfor,concept:company:lenovo': <sfe.Node at 0x7f3f72ba31d0>,
#  nan: <sfe.Node at 0x7f3f719add10>,
#  nan: <sfe.Node at 0x7f3f740e3b10>,
#  '21625,concept:person:president,concept:hasspouse,concept:celebrity:laura_bush': <sfe.Node at 0x7f3f701d3110>,
#  '10886,concept:city:northampton,concept:atlocation,concept:stateorprovince:massachusetts': <sfe.Node at 0x7f3f723ba250>,
#  nan: <sfe.Node at 0x7f3f6ea9d310>,
#  '7866,concept:radiostation:wtmj_tv,concept:subpartoforganization,concept:company:nbc,1': <sfe.Node at 0x7f3f6dba0d50>,
#  '29284,concept:televisionstation:wfyi,concept:subpartof,concept:museum:pbs': <sfe.Node at 0x7f3f6ec2c350>,
#  '17665,concept:journalist:dan_shaughnessy,concept:journalistwritesforpublication,concept:newspaper:the_boston_globe': <sfe.Node at 0x7f3f70d7f590>,
#  nan: <sfe.Node at 0x7f3f7269fe50>,
#  '24621,concept:radiostation:montana,concept:subpartof,concept:country:us_canada': <sfe.Node at 0x7f3f6f95e2d0>,
#  '8536,concept:sportsteam:iowa_hawkeyes,concept:organizationhiredperson,concept:coach:kirk_ferentz,1': <sfe.Node at 0x7f3f6da9d790>,
#  '18689,concept:male:woodrow_wilson,concept:politicianusholdsoffice,concept:politicaloffice:president': <sfe.Node at 0x7f3f70a60d90>,
#  nan: <sfe.Node at 0x7f3f6e1c9d50>,
#  nan: <sfe.Node at 0x7f3f70174090>,
#  '2390,concept:arthropod:pests,concept:animalthatfeedoninsect,concept:insect:weevils': <sfe.Node at 0x7f3f73d297d0>,
#  '24640,concept:radiostation:ut,concept:companyeconomicsector,concept:economicsector:insurance': <sfe.Node at 0x7f3f6f95ec50>,
#  '8638,concept:sportsteam:minnesota_vikings,concept:teamhomestadium,concept:stadiumoreventvenue:metrodome,1': <sfe.Node at 0x7f3f6dacc190>,
#  '18782,concept:mammal:cats,concept:animaldevelopdisease,concept:disease:fiv': <sfe.Node at 0x7f3f70a25cd0>,
#  '6984,concept:bodypart:cord001,concept:bodypartcontainsbodypart,concept:bodypart:tract001': <sfe.Node at 0x7f3f72f14450>,
#  '9906,concept:website:issue,concept:subpartof,concept:weatherphenomenon:water,1': <sfe.Node at 0x7f3f6d898390>,
#  '9226,concept:chemical:volatile_organic_compounds,concept:chemicalistypeofchemical,concept:chemical:nitrogen': <sfe.Node at 0x7f3f72876710>,
#  '1791,concept:animal:larger_animals,concept:animalpreyson,concept:agriculturalproduct:pigs': <sfe.Node at 0x7f3f73e75790>,
#  nan: <sfe.Node at 0x7f3f6fdf56d0>,
#  '17044,concept:hallwayitem:pump,concept:subpartof,concept:weatherphenomenon:water': <sfe.Node at 0x7f3f70f32a10>,
#  '1210,concept:athlete:jeremy_shockey,concept:athleteplayssport,concept:sport:football,1': <sfe.Node at 0x7f3f6e52f310>,
#  '18616,concept:male:mahalaleel,concept:fatherofperson,concept:personaustralia:jared': <sfe.Node at 0x7f3f70ab1890>,
#  '12120,concept:clothing:shirts,concept:clothingtogowithclothing,concept:clothing:hoodies': <sfe.Node at 0x7f3f71d2c510>,
#  '10495,concept:city:largo,concept:atlocation,concept:stateorprovince:florida': <sfe.Node at 0x7f3f7250fb90>,
#  nan: <sfe.Node at 0x7f3f72af1f50>,
#  '29397,concept:televisionstation:wnin,concept:subpartof,concept:museum:pbs': <sfe.Node at 0x7f3f6ebf2c90>,
#  nan: <sfe.Node at 0x7f3f73b50290>,
#  nan: <sfe.Node at 0x7f3f6e1c9b50>,
#  nan: <sfe.Node at 0x7f3f70e6aa50>,
#  '4525,concept:athlete:rafael_furcal,concept:athleteplayssport,concept:sport:baseball': <sfe.Node at 0x7f3f73611350>,
#  '13981,concept:company:yahoo,concept:competeswith,concept:company:aol_': <sfe.Node at 0x7f3f717f9650>,
#  nan: <sfe.Node at 0x7f3f6dab5990>,
#  '27402,concept:sportsteam:pittsburg_state_gorillas,concept:subpartoforganization,concept:sportsteam:ncaa': <sfe.Node at 0x7f3f6f1c7750>,
#  '11088,concept:city:pyay,concept:cityalsoknownas,concept:city:prome': <sfe.Node at 0x7f3f720348d0>,
#  '18902,concept:mammal:dogs,concept:animalpreyson,concept:mammal:domestic_animals': <sfe.Node at 0x7f3f70a009d0>,
#  '23935,concept:politicianus:john_mccain_s,concept:politicianusendorsedbypoliticianus,concept:politicianus:palin': <sfe.Node at 0x7f3f6fb63650>,
#  '6816,concept:person:kate,concept:personmovedtostateorprovince,concept:stateorprovince:new_york_city,1': <sfe.Node at 0x7f3f6dd302d0>,
#  nan: <sfe.Node at 0x7f3f6e649ed0>,
#  nan: <sfe.Node at 0x7f3f6efab950>,
#  nan: <sfe.Node at 0x7f3f71989610>,
#  '16871,concept:furniture:sofa_sleepers,concept:furniturefoundinroom,concept:room:living_room': <sfe.Node at 0x7f3f70fbf250>,
#  nan: <sfe.Node at 0x7f3f6fb290d0>,
#  nan: <sfe.Node at 0x7f3f706a60d0>,
#  '27229,concept:sportsteam:northern_iowa,concept:teamplaysinleague,concept:sportsleague:ncaa': <sfe.Node at 0x7f3f6f23df50>,
#  nan: <sfe.Node at 0x7f3f73583dd0>,
#  nan: <sfe.Node at 0x7f3f7074ac50>,
#  '16890,concept:furniture:vanities,concept:furniturefoundinroom,concept:room:master_bath': <sfe.Node at 0x7f3f70fbfbd0>,
#  '31103,concept:writer:greenspan,concept:personleadsorganization,concept:governmentorganization:fed': <sfe.Node at 0x7f3f6e74df10>,
#  nan: <sfe.Node at 0x7f3f70d16090>,
#  nan: <sfe.Node at 0x7f3f6e74dc50>,
#  nan: <sfe.Node at 0x7f3f6e365d10>,
#  nan: <sfe.Node at 0x7f3f6edbc710>,
#  '18076,concept:language:english,concept:languageofcountry,concept:country:fiji': <sfe.Node at 0x7f3f70c2a650>,
#  '23111,concept:politician:alex_sink,concept:personhasresidenceingeopoliticallocation,concept:stateorprovince:florida': <sfe.Node at 0x7f3f6fe0d3d0>,
#  nan: <sfe.Node at 0x7f3f732f1290>,
#  '5745,concept:automobilemaker:vw,concept:automakerproducesmodel,concept:automobilemodel:passat': <sfe.Node at 0x7f3f7327aed0>,
#  '14803,concept:drug:effexor,concept:drugpossiblytreatsphysiologicalcondition,concept:disease:pain': <sfe.Node at 0x7f3f715507d0>,
#  nan: <sfe.Node at 0x7f3f73b830d0>,
#  nan: <sfe.Node at 0x7f3f71b78850>,
#  '18536,concept:male:constantine,concept:personhasjobposition,concept:jobposition:king': <sfe.Node at 0x7f3f70aecfd0>,
#  '5354,concept:automobilemaker:ford,concept:producesproduct,concept:automobilemodel:windstar': <sfe.Node at 0x7f3f73367850>,
#  nan: <sfe.Node at 0x7f3f6de32cd0>,
#  '2728,concept:chemical:emissions,concept:chemicalistypeofchemical,concept:chemical:production,1': <sfe.Node at 0x7f3f6e2d8490>,
#  nan: <sfe.Node at 0x7f3f6f100690>,
#  nan: <sfe.Node at 0x7f3f6df5a610>,
#  nan: <sfe.Node at 0x7f3f718874d0>,
#  nan: <sfe.Node at 0x7f3f6ec7eb90>,
#  '25580,concept:sport:tennis,concept:sportusesequipment,concept:sportsequipment:backboard': <sfe.Node at 0x7f3f6f6909d0>,
#  '13504,concept:company:ibm001,concept:headquarteredin,concept:city:zurich': <sfe.Node at 0x7f3f71921410>,
#  '21478,concept:person:meg_whitman,concept:worksfor,concept:company:ebay003': <sfe.Node at 0x7f3f7025f650>,
#  '26580,concept:sportsteam:hampshire,concept:subpartoforganization,concept:sportsteam:ncaa': <sfe.Node at 0x7f3f6f3f15d0>,
#  '2093,concept:artery:axillary,concept:arterycalledartery,concept:artery:arteries': <sfe.Node at 0x7f3f73ddb110>,
#  nan: <sfe.Node at 0x7f3f6e23e7d0>,
#  '3394,concept:city:maputo,concept:citylocatedincountry,concept:country:mozambique,1': <sfe.Node at 0x7f3f6e23ed90>,
#  nan: <sfe.Node at 0x7f3f6dcba590>,
#  '28473,concept:stateorprovince:madhya_pradesh,concept:locationlocatedwithinlocation,concept:country:india__': <sfe.Node at 0x7f3f6ee56750>,
#  nan: <sfe.Node at 0x7f3f72e87dd0>,
#  nan: <sfe.Node at 0x7f3f7321c250>,
#  nan: <sfe.Node at 0x7f3f73882990>,
#  nan: <sfe.Node at 0x7f3f72b953d0>,
#  nan: <sfe.Node at 0x7f3f6f793fd0>,
#  nan: <sfe.Node at 0x7f3f731ca550>,
#  nan: <sfe.Node at 0x7f3f7303aad0>,
#  '22037,concept:personafrica:andrew_stanton,concept:directordirectedmovie,concept:movie:finding_nemo': <sfe.Node at 0x7f3f700fe250>,
#  '14174,concept:country:jamaica,concept:countrycurrency,concept:currency:dollars': <sfe.Node at 0x7f3f71784850>,
#  '1739,concept:animal:herbivores,concept:animalpreyson,concept:agriculturalproduct:pigs': <sfe.Node at 0x7f3f73ec7d10>,
#  nan: <sfe.Node at 0x7f3f705deb50>,
#  nan: <sfe.Node at 0x7f3f6e0eac10>,
#  '4528,concept:athlete:rafael_nadal,concept:athletewinsawardtrophytournament,concept:awardtrophytournament:roland_garros': <sfe.Node at 0x7f3f736114d0>,
#  '23410,concept:politicianus:barbara_boxer,concept:personhasresidenceinstateorprovince,concept:stateorprovince:california': <sfe.Node at 0x7f3f6fcdbb90>,
#  nan: <sfe.Node at 0x7f3f6e100550>,
#  nan: <sfe.Node at 0x7f3f6eb64710>,
#  nan: <sfe.Node at 0x7f3f6edbc290>,
#  nan: <sfe.Node at 0x7f3f73d4df90>,
#  nan: <sfe.Node at 0x7f3f6f021b50>,
#  '8969,concept:chemical:nitrogen_dioxide,concept:chemicalistypeofchemical,concept:chemical:gases': <sfe.Node at 0x7f3f7293e490>,
#  nan: <sfe.Node at 0x7f3f6eab3fd0>,
#  '20024,concept:musician:eric,concept:musicianplaysinstrument,concept:musicinstrument:vocals': <sfe.Node at 0x7f3f706bd3d0>,
#  '4144,concept:coach:sylvester_croom,concept:worksfor,concept:university:mississippi_state,1': <sfe.Node at 0x7f3f6e0d2c10>,
#  '12586,concept:coach:brad_childress,concept:coachesinleague,concept:sportsleague:nfl': <sfe.Node at 0x7f3f71c041d0>,
#  nan: <sfe.Node at 0x7f3f6fe83890>,
#  nan: <sfe.Node at 0x7f3f72955690>,
#  nan: <sfe.Node at 0x7f3f72635f10>,
#  nan: <sfe.Node at 0x7f3f728df710>,
#  nan: <sfe.Node at 0x7f3f712d4e10>,
#  nan: <sfe.Node at 0x7f3f6e838850>,
#  '20162,concept:musician:marty_friedman,concept:musicianinmusicartist,concept:musicartist:megadeth': <sfe.Node at 0x7f3f706199d0>,
#  '528,concept:animal:child,concept:animaleatfood,concept:food:healthy_diet,1': <sfe.Node at 0x7f3f6e6335d0>,
#  '22628,concept:planet:fresh_water,concept:subpartof,concept:hallwayitem:system': <sfe.Node at 0x7f3f6ff1de50>,
#  nan: <sfe.Node at 0x7f3f71e69ad0>,
#  '22697,concept:plant:cork_oaks,concept:plantincludeplant,concept:plant:trees': <sfe.Node at 0x7f3f6fee2190>,
#  '25911,concept:sportsteam:baltimore_ravens,concept:teamwontrophy,concept:awardtrophytournament:afc_championship_game': <sfe.Node at 0x7f3f6f60d210>,
#  '16234,concept:furniture:beds,concept:furniturefoundinroom,concept:room:back_room': <sfe.Node at 0x7f3f7115be90>,
#  nan: <sfe.Node at 0x7f3f72c46910>,
#  '21617,concept:person:philip,concept:personbornincity,concept:city:york': <sfe.Node at 0x7f3f7023ccd0>,
#  '31008,concept:wine:gris,concept:beveragemadefrombeverage,concept:wine:pinot': <sfe.Node at 0x7f3f6e787ed0>,
#  '30177,concept:visualartist:braque,concept:visualartistartform,concept:visualartform:paintings': <sfe.Node at 0x7f3f6e9b18d0>,
#  nan: <sfe.Node at 0x7f3f70379e10>,
#  nan: <sfe.Node at 0x7f3f72034d10>,
#  nan: <sfe.Node at 0x7f3f73d72490>,
#  '28189,concept:sportsteam:yankees,concept:teamalsoknownas,concept:sportsteam:chicago_white_sox': <sfe.Node at 0x7f3f6ef87710>,
#  nan: <sfe.Node at 0x7f3f7195c210>,
#  nan: <sfe.Node at 0x7f3f71cb6950>,
#  nan: <sfe.Node at 0x7f3f709c6e50>,
#  nan: <sfe.Node at 0x7f3f6e7fdc10>,
#  '21818,concept:person:sills,concept:personleadsorganization,concept:organization:city_opera': <sfe.Node at 0x7f3f7015d310>,
#  nan: <sfe.Node at 0x7f3f6f580210>,
#  '29549,concept:televisionstation:wxvt,concept:subpartof,concept:website:cbs': <sfe.Node at 0x7f3f6eb649d0>,
#  '8648,concept:chemical:ethanol,concept:chemicalistypeofchemical,concept:chemical:products': <sfe.Node at 0x7f3f72a58190>,
#  '12866,concept:coach:mark_hendrickson,concept:athleteplaysinleague,concept:sportsleague:mlb': <sfe.Node at 0x7f3f71b3dfd0>,
#  '5676,concept:journalist:jayson_stark,concept:journalistwritesforpublication,concept:website:espn,1': <sfe.Node at 0x7f3f6de91150>,
#  '27476,concept:sportsteam:red_sox,concept:teamalsoknownas,concept:sportsteam:indians': <sfe.Node at 0x7f3f6f175cd0>,
#  nan: <sfe.Node at 0x7f3f72852c50>,
#  '25908,concept:sportsteam:baltimore_ravens,concept:organizationhiredperson,concept:coach:john_harbaugh': <sfe.Node at 0x7f3f6f60d090>,
#  '24364,concept:politicianus:tom_daschle,concept:politicianusmemberofpoliticalgroup,concept:organization:senate': <sfe.Node at 0x7f3f6fa25050>,
#  nan: <sfe.Node at 0x7f3f6dd54090>,
#  nan: <sfe.Node at 0x7f3f6f7c12d0>,
#  ...}
